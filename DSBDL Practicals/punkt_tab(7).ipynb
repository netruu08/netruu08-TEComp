# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\netra\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\netra\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\netra\anaconda3\lib\site-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\netra\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\netra\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\netra\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\NETRA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

text = """Hello Mr. Smith, how are you doing today? The weather is great, and the city is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."""
tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and the city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard."]

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'the', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 26 samples and 32 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('is', 3), ('.', 3)]

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'haven', 'only', 'didn', "we've", "hadn't", 'while', 'wouldn', 'but', "i'm", 'so', 'which', 'such', 'needn', 'are', 'not', 'now', 'our', 'under', 'doesn', 'with', 'above', "we'd", 'was', 'on', 'if', 'their', "they're", 'we', 'over', 'won', 'you', 'they', 'an', "aren't", 'some', 'myself', "we're", 'mightn', "she'll", 'again', 'couldn', 'shouldn', 'the', 'ma', 'wasn', 'each', "i'll", 'at', 'further', 'all', 'of', "shouldn't", "haven't", 'will', 'my', 'mustn', "they've", 'can', 'when', 'does', "he'd", "should've", 'same', 'she', 's', 'isn', 'being', "doesn't", 'few', "you'll", "they'll", "don't", 'herself', 'off', 'doing', 'is', 'shan', "couldn't", 'more', 'y', "needn't", 'that', 'weren', 'through', 'just', 'have', 'from', "hasn't", 'yourself', 'as', "it'd", 'nor', 'and', 'm', 'what', "you'd", 'it', 'hadn', 'them', 'very', 'he', 'ain', 'below', 'i', 'been', 'themselves', 'any', 'no', 'its', "that'll", 'where', 'own', 'a', "shan't", 'up', 'for', "he's", 'in', 'most', 'your', 'having', 'other', 'am', "i'd", 'by', 'yourselves', 'be', 'll', "you've", 'his', "you're", "mightn't", "weren't", 'too', "it'll", 'o', 'until', 'about', 'were', 'between', 'did', 'down', 'or', 'to', "it's", 'hers', 'this', 'who', 'don', 'out', 'during', 'here', "she's", "they'd", 'whom', "won't", 'before', 'him', 'should', 'has', 'after', 'ourselves', 'both', 'himself', "we'll", 'hasn', 'against', 'her', 'ours', "isn't", 'than', 't', 'those', 'itself', 'aren', "wasn't", 'then', "didn't", "i've", 'yours', 'once', 'how', 'these', 'why', 'into', 'me', 're', 'because', "mustn't", 'theirs', 'had', 'do', "she'd", "he'll", "wouldn't", 've', 'd', 'there'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\NETRA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
text1="""Hello Mr.smith,how are you doing today?"""
tokenized_sent=word_tokenize(text1)
print(tokenized_sent)
filtered_sent=[]
for w in tokenized_sent:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentences:",tokenized_sent)
print("Filtered Sentence:",filtered_sent)
# Out:
# ['Hello', 'Mr.smith', ',', 'how', 'are', 'you', 'doing', 'today', '?']
# Tokenized Sentences: ['Hello', 'Mr.smith', ',', 'how', 'are', 'you', 'doing', 'today', '?']
# Filtered Sentence: ['Hello', 'Mr.smith', ',', 'today', '?']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))
    
print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['Hello', 'Mr.smith', ',', 'today', '?']
# Stemmed Sentence: ['hello', 'mr.smith', ',', 'today', '?']

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "flying"
print("Lemmenized word:",lem.lemmatize(word,"v"))
print("Stemmed word:",stem.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\NETRA\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\NETRA\AppData\Roaming\nltk_data...
# Lemmenized word: fly
# Stemmed word: fli

# %%
sent = "Albert Einstein was born in Ulm,Germant in 1879."

# %%
tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germant', 'in', '1879', '.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
nltk.pos_tag(tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\NETRA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germant', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "Sachin was the GOAT of the previous generation",
    "Virat is the GOAT of the this generation",
    "Shubman will be the GOAT of the next generation"
]
vectorizer = TfidfVectorizer()

# %%
matrix = vectorizer.fit(corpus)
matrix.vocabulary_
# Out:
# {'sachin': 7,
#  'was': 12,
#  'the': 9,
#  'goat': 2,
#  'of': 5,
#  'previous': 6,
#  'generation': 1,
#  'virat': 11,
#  'is': 3,
#  'this': 10,
#  'shubman': 8,
#  'will': 13,
#  'be': 0,
#  'next': 4}

# %%
tfidf_matrix = vectorizer.transform(corpus)
print(tfidf_matrix)
# Out:
#   (0, 1)	0.25318287697299496
#   (0, 2)	0.25318287697299496
#   (0, 5)	0.25318287697299496
#   (0, 6)	0.4286758743128819
#   (0, 7)	0.4286758743128819
#   (0, 9)	0.5063657539459899
#   (0, 12)	0.4286758743128819
#   (1, 1)	0.25318287697299496
#   (1, 2)	0.25318287697299496
#   (1, 3)	0.42867587431288195
#   (1, 5)	0.25318287697299496
#   (1, 9)	0.5063657539459899
#   (1, 10)	0.42867587431288195
#   (1, 11)	0.42867587431288195
#   (2, 0)	0.39400039808922477
#   (2, 1)	0.23270298212286766
#   (2, 2)	0.23270298212286766
#   (2, 4)	0.39400039808922477
#   (2, 5)	0.23270298212286766
#   (2, 8)	0.39400039808922477
#   (2, 9)	0.4654059642457353
#   (2, 13)	0.39400039808922477

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['be' 'generation' 'goat' 'is' 'next' 'of' 'previous' 'sachin' 'shubman'
#  'the' 'this' 'virat' 'was' 'will']
